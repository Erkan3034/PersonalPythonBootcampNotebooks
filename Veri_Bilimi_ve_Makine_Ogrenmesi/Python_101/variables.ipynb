# %%
x=5
print(x)

# %%
3+5
# Out:
# 8

# %%
age = 50

# %%
age/2
# Out:
# 25.0

# %%
age//2
# Out:
# 25

# %%
age % 5
# Out:
# 0

# %%
floatVariable= 15.5

# %%
floatVariable
# Out:
# 15.5

# %%
intToVariable=int(floatVariable)

# %%
intToVariable
# Out:
# 15
