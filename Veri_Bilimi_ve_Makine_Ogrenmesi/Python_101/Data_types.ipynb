# %% [markdown]
# ## Data Types

# %%
type(1205)
# Out:
# int

# %%
type(-10)
# Out:
# int

# %%
type("Erkan Turgut")
# Out:
# str

# %%
type(12.5)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type(['a','b'])
# Out:
# list

# %%
type((2,3,4,5))
# Out:
# tuple

# %%
type(10*3)
# Out:
# int

# %% [markdown]
# ## int vs Float

# %%
4 / 2
# Out:
# 2.0

# %%
type(4/2)
# Out:
# float

# %%
type(4)
# Out:
# int

# %%
type(2)
# Out:
# int

# %%
type(4+2)
# Out:
# int

# %%
15/5
# Out:
# 3.0

# %%
15/4
# Out:
# 3.75

# %%
# Bölmelerde int/int =  float tipindedir.

# %%
type(4.5-2)
# Out:
# float
