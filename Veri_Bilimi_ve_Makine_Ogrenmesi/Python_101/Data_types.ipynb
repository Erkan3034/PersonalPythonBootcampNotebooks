# %% [markdown]
# ## Data Types

# %%
type(1205)
# Out:
# int

# %%
type("Erkan Turgut")
# Out:
# str

# %%
type(12.5)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type(['a','b'])
# Out:
# list

# %%
type((2,3,4,5))
# Out:
# tuple
