# %% [markdown]
# # Strings

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello world")
# Out:
# hello world

# %%
name = "erkan"

# %%
type(name)
# Out:
# str

# %%
name.capitalize()
# Out:
# 'Erkan'

# %%
x=12

# %%
type(x)
# Out:
# int

# %%
x.to_bytes()
# Out:
# b'\x0c'

# %%
x.is_integer()
# Out:
# True
